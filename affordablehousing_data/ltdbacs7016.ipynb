# %%
import pandas as pd
import numpy as np
pd.options.display.max_columns = None
pd.options.display.max_colwidth = 100

# %%
fc70 = pd.read_csv('LTDB/durham_ltdb_std70_fullcount.csv')
s70 = pd.read_csv('LTDB/durham_ltdb_std70_sample.csv')
std70 = pd.merge(fc70,s70,on='trtid10')
std70columns = ['trtid10', 'pop70', 'white70','pwhite70','black70','pblack70','asian70','pasian70','haw70',
                'phaw70','hu70','vac70','pvac70','ohu70','pohu70','own70','pown70','rent70','prent70',
                'mhmval70a17','mhmval70','mrent70','mrent70a17','hinc70','hinc70a17','ag25up70','hs70','phs70',
                'col70','pcol70','clf70','unemp70','punemp70']
std70 = std70[std70columns]
std70.rename(columns={'white70':'nhwht70','pwhite70':'pnhwht70','black70':'nhblk70','pblack70':'pnhblk70'},
             inplace=True)
std70.head()
# Out:
#        trtid10        pop70      nhwht70   pnhwht70      nhblk70   pnhblk70  \
# 0  37063000101  3406.126516  3224.728180  94.674351   169.503558   4.976432
# 1  37063000102  4038.609379  3823.766645  94.680279   200.736893   4.970446
# 2  37063000200  2710.963965  2282.969654  84.212468   415.994476  15.344891
# 3  37063000301  2981.000049  1600.000026  53.673264  1370.000000  45.957732
# 4  37063000302  3695.000014  3550.000014  96.075778   120.000000   3.247632
#
#      asian70  pasian70  haw70  phaw70         hu70      vac70    pvac70  \
# 0  11.437042  0.335779    0.0     0.0  1220.306213  26.553145  2.175941
# 1  13.563304  0.335841    0.0     0.0  1446.933228  31.466866  2.174728
# 2   8.999881  0.331981    0.0     0.0  1099.985352  70.999054  6.454545
# 3   4.000000  0.134183    0.0     0.0  1179.000000  61.000000  5.173876
# 4  16.000000  0.433018    0.0     0.0  1580.000000  68.000000  4.303797
#
#          ohu70     pohu70       own70     pown70      rent70    prent70  \
# ...

# %%
fc80 = pd.read_csv('LTDB/durham_ltdb_std80_fullcount.csv')
s80 = pd.read_csv('LTDB/durham_ltdb_std80_sample.csv')
std80 = pd.merge(fc80,s80,on='trtid10')
std80columns = ['trtid10', 'pop80', 'nhwht80','pnhwht80','nhblk80','pnhblk80','ntv80','pntv80',
                'asian80','pasian80','hisp80','phisp80','haw80','phaw80','hu80','vac80','pvac80',
                'ohu80','pohu80','own80','pown80','rent80','prent80', 'mhmval80','mhmval80a17',
                'mrent80','mrent80a17','hinc80','hinc80a17','hincw80','hincw80a17','hincb80','hincb80a17',
                'hinch80','hinch80a17','hinca80','hinca80a17','ag25up80','hs80','phs80','col80','pcol80',
                'clf80','unemp80','punemp80']
std80 = std80[std80columns]
std80.head()
# Out:
#        trtid10        pop80      nhwht80   pnhwht80      nhblk80   pnhblk80  \
# 0  37063001802  4032.269137  1993.220303  49.431728  1997.042318  49.526513
# 1  37063002007  2592.596845  2123.167423  81.893466   421.307840  16.250419
# 2  37063000301  2409.000039  1142.000000  47.405562  1226.000000  50.892486
# 3  37063002100  2716.001445  2009.001191  73.969077   675.000238  24.852720
# 4  37063001502  3783.433794  2943.633850  77.803234   707.515991  18.700367
#
#       ntv80    pntv80    asian80  pasian80     hisp80   phisp80     haw80  \
# 0  1.000131  0.024803   1.003177  0.024879  39.002260  0.967253  0.000000
# 1  3.208002  0.123737  21.387990  0.824964  18.713749  0.721815  0.000000
# 2  2.000000  0.083022  19.000000  0.788709  14.000000  0.581154  2.000000
# 3  4.000001  0.147275   4.000008  0.147276  24.000008  0.883652  1.000000
# 4  7.600148  0.200880  67.316696  1.779249  46.411952  1.226715  0.320955
#
# ...

# %%
fc90 = pd.read_csv('LTDB/durham_ltdb_std90_fullcount.csv')
s90 = pd.read_csv('LTDB/durham_ltdb_std90_sample.csv')
std90 = pd.merge(fc90,s90,on='trtid10')
std90columns = ['trtid10', 'pop90', 'nhwht90','pnhwht90','nhblk90','pnhblk90','ntv90','pntv90',
                'asian90','pasian90','hisp90','phisp90','haw90','phaw90','hu90','vac90','pvac90',
                'ohu90','pohu90','own90','pown90','rent90','prent90', 'mhmval90','mhmval90a17',
                'mrent90','mrent90a17','hinc90','hinc90a17','hincw90','hincw90a17','hincb90','hincb90a17',
                'hinch90','hinch90a17','hinca90','hinca90a17','ag25up90','hs90','phs90','col90','pcol90',
                'clf90','unemp90','punemp90']
std90 = std90[std90columns]
std90.head()
# Out:
#        trtid10        pop90      nhwht90   pnhwht90      nhblk90   pnhblk90  \
# 0  37063000101  2881.037191  1485.020388  51.544645  1349.016177  46.823976
# 1  37063000102  3637.000076  2845.000060  78.223811   692.000000  19.026670
# 2  37063000200  2801.962755  1535.979583  54.817987  1217.983765  43.468949
# 3  37063000301  2337.000038   910.000015  38.938810  1364.000000  58.365425
# 4  37063000302  3352.000013  2420.000009  72.195704   827.000000  24.671838
#
#        ntv90    pntv90    asian90  pasian90     hisp90   phisp90  haw90  \
# 0   8.000066  0.277680  14.000305  0.485947  25.000266  0.867752    0.0
# 1  11.000000  0.302447  32.000000  0.879846  52.000000  1.429750    0.0
# 2   4.999934  0.178444  22.999695  0.820842  19.999735  0.713776    0.0
# 3   7.000000  0.299529  22.000000  0.941378  31.000000  1.326487    0.0
# 4   2.000000  0.059666  32.000000  0.954654  68.000000  2.028640    1.0
#
#      phaw90         hu90       vac90    pvac90        ohu90     pohu90  \
# ...

# %%
fc00 = pd.read_csv('LTDB/durham_ltdb_std00_fullcount.csv')
s9800 = pd.read_csv('LTDB/durham_propsale_ltdb_std9800_sample.csv')
std9800 = pd.merge(fc00,s9800,on='trtid10')
std9800columns = ['trtid10', 'pop00', 'nhwht00','pnhwht00','nhblk00','pnhblk00','ntv00','pntv00',
                  'asian00','pasian00','hisp00','phisp00','haw00','phaw00','hu00','vac00','pvac00',
                  'ohu00','pohu00','own00','pown00','rent00','prent00', 'mhmval00','mhmval00a17',
                  'mrent00','mrent00a17','hinc00','hinc00a17','hincw00','hincw00a17','hincb00','hincb00a17',
                  'hinch00','hinch00a17','hinca00','hinca00a17','meansp9800','minsp9800','maxsp9800',
                  'mediansp9800','stddevsp9800','totsp9800','nums9800','meansp9800a17','minsp9800a17',
                  'maxsp9800a17','mediansp9800a17','totsp9800a17','pir9800','ag25up00',
                  'hs00','phs00','col00','pcol00','clf00','unemp00','punemp00']
std9800 = std9800[std9800columns]
std9800.head()
# Out:
#        trtid10        pop00      nhwht00   pnhwht00      nhblk00   pnhblk00  \
# 0  37063000101  3151.041386  1056.013813  33.513169  1704.020773  54.078019
# 1  37063000102  4462.000000  2107.000000  47.220977  1417.000000  31.757060
# 2  37063000200  3115.958583  1039.986206  33.376124  1563.979248  50.192556
# 3  37063000301  2432.000000   669.000000  27.508224  1299.000000  53.412829
# 4  37063000302  3449.000000  2067.000000  59.930415   878.000000  25.456654
#
#        ntv00    pntv00    asian00  pasian00      hisp00    phisp00  haw00  \
# 0  28.000159  0.888600  52.000465  1.650263  303.005990   9.616059    0.0
# 1  26.000000  0.582698  55.000000  1.232631  852.000000  19.094576    0.0
# 2  11.999841  0.385109  34.999535  1.123235  450.994019  14.473685    0.0
# 3   9.000000  0.370066  41.000000  1.685855  399.000000  16.406250    0.0
# 4  13.000000  0.376921  86.000000  2.493476  387.000000  11.220644    0.0
#
# ...

# %%
fc10 = pd.read_csv('LTDB/durham_ltdb_std10_fullcount.csv')
s0712 = pd.read_csv('LTDB/durham_propsale_ltdb_std0712_sample.csv')
std0712 = pd.merge(fc10,s0712,on='trtid10')
std0712columns = ['trtid10', 'pop10', 'nhwht10','pnhwht10','nhblk10','pnhblk10','ntv10','pntv10',
                  'asian10','pasian10','hisp10','phisp10','haw10','phaw10','hu10','vac10','pvac10',
                  'ohu10','pohu10','own10','pown10','rent10','prent10', 'mhmval12','mhmval12a17',
                  'mrent12','mrent12a17','hinc12','hinc12a17','hincw12','hincw12a17','hincb12','hincb12a17',
                  'hinch12','hinch12a17','hinca12','hinca12a17','meansp0709','minsp0709','maxsp0709',
                  'mediansp0709','stddevsp0709','totsp0709','nums0709','meansp0709a17','minsp0709a17',
                  'maxsp0709a17','mediansp0709a17','totsp0709a17','pir0712','ag25up12',
                  'hs12','phs12','col12','pcol12','clf12','unemp12','punemp12']
std0712 = std0712[std0712columns]

std0712['pccol0012'] = std0712.pcol12.astype('float64').subtract(std9800.pcol00.astype('float64'),fill_value='NaN')

std0712['pcnhwht0010'] = std0712.cpnhwht10.astype('float64').subtract(std9800.pnhwht00.astype('float64'),fill_value='NaN')
std0712['pcnhblk0010'] = std0712.cpnhblk10.astype('float64').subtract(std9800.pnhblk00.astype('float64'),fill_value='NaN')
std0712['pcasian0010'] = std0712.cpasian10.astype('float64').subtract(std9800.pasian00.astype('float64'),fill_value='NaN')
std0712['pchisp0010'] = std0712.cphisp10.astype('float64').subtract(std9800.phisp00.astype('float64'),fill_value='NaN')

std0712['cmhmval0012a17'] = std0712.mhmval12a17.astype('float64').subtract(std9800.mhmval00a17.astype('float64'),fill_value='NaN')
std0712['pcmhmval0012a17'] = 100.0*(std0712.cmhmval0012a17.astype('float64')/std9800.mhmval00a17.astype('float64'))
std0712['cmrent0012a17'] = std0712.mrent12a17.astype('float64').subtract(std9800.mrent00a17.astype('float64'),fill_value='NaN')
std0712['pcmrent0012a17'] = 100.0*(std0712.cmrent0012a17.astype('float64')/std9800.mrent00a17.astype('float64'))

std0712['chinc0012a17'] = std0712.hinc12a17.astype('float64').subtract(std9800.hinc00a17.astype('float64'),fill_value='NaN')
std0712['chincw0012a17'] = std0712.hincw12a17.astype('float64').subtract(std9800.hincw00a17.astype('float64'),fill_value='NaN')
std0712['chincb0012a17'] = std0712.hincb12a17.astype('float64').subtract(std9800.hincb00a17.astype('float64'),fill_value='NaN')
std0712['chinca0012a17'] = std0712.hinca12a17.astype('float64').subtract(std9800.hinca00a17.astype('float64'),fill_value='NaN')
std0712['chinch0012a17'] = std0712.hinch12a17.astype('float64').subtract(std9800.hinch00a17.astype('float64'),fill_value='NaN')
std0712['cmeansp0009a17'] = std0712.meansp0709a17.astype('float64').subtract(std9800.meansp9800a17.astype('float64'),fill_value='NaN')
std0712['cmediansp0009a17'] = std0712.mediansp0709a17.astype('float64').subtract(std9800.mediansp9800a17.astype('float64'),fill_value='NaN')

std0712['pchinc0012a17'] = 100.0*(std0712.chinc0012a17.astype('float64')/std9800.hinc00a17.astype('float64'))
std0712['pchincw0012a17'] = 100.0*(std0712.chincw0012a17.astype('float64')/std9800.hincw00a17.astype('float64'))
std0712['pchincb0012a17'] = 100.0*(std0712.chincb0012a17.astype('float64')/std9800.hincb00a17.astype('float64'))
std0712['pchinca0012a17'] = 100.0*(std0712.chinca0012a17.astype('float64')/std9800.hinca00a17.astype('float64'))
std0712['pchinch0012a17'] = 100.0*(std0712.chinch0012a17.astype('float64')/std9800.hinch00a17.astype('float64'))
std0712['pcmeansp0009a17'] = 100.0*(std0712.cmeansp0009a17.astype('float64')/std9800.meansp9800a17.astype('float64'))
std0712['pcmediansp0009a17'] = 100.0*(std0712.cmediansp0009a17.astype('float64')/std9800.mediansp9800a17.astype('float64'))

std0712.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-dad891d19453> in <module>()
#      14 std0712['pccol0012'] = std0712.pcol12.astype('float64').subtract(std9800.pcol00.astype('float64'),fill_value='NaN')
#      15
# ---> 16 std0712['pcnhwht0010'] = std0712.cpnhwht10.astype('float64').subtract(std9800.pnhwht00.astype('float64'),fill_value='NaN')
#      17 std0712['pcnhblk0010'] = std0712.cpnhblk10.astype('float64').subtract(std9800.pnhblk00.astype('float64'),fill_value='NaN')
#      18 std0712['pcasian0010'] = std0712.cpasian10.astype('float64').subtract(std9800.pasian00.astype('float64'),fill_value='NaN')
#
# /home/jmcmanus/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    2968             if name in self._info_axis:
#    2969                 return self[name]
# ...

# %%
stdall = pd.merge(std70,std80,on='trtid10')
stdall = stdall.merge(std90,on='trtid10')
stdall = stdall.merge(std9800,on='trtid10')
stdall = stdall.merge(std0712,on='trtid10')

# %%
stdall.head()

# %%
acspop16tr = pd.read_csv('acs/acs_population_2016_tr.csv')
acspop16trcolumns = ['id','pop16','nhwht16','pnhwht16','nhblk16','pnhblk16','ntv16','pntv16','asian16',
                     'pasian16','haw16','phaw16','oth16','poth16','twomr16','ptwomr16','hisp16','phisp16']
acspop16tr = acspop16tr[acspop16trcolumns]
acspop16tr.head()

# %%
acspop16tr.replace(to_replace='-',value=np.nan,inplace=True)

acspop16tr['pcnhwht0016'] = acspop16tr.pnhwht16.astype('float64').subtract(std9800.pnhwht00.astype('float64'),fill_value='NaN')
acspop16tr['pcnhblk0016'] = acspop16tr.pnhblk16.astype('float64').subtract(std9800.pnhblk00.astype('float64'),fill_value='NaN')
acspop16tr['pcasian0016'] = acspop16tr.pasian16.astype('float64').subtract(std9800.pasian00.astype('float64'),fill_value='NaN')
acspop16tr['pchisp0016'] = acspop16tr.phisp16.astype('float64').subtract(std9800.phisp00.astype('float64'),fill_value='NaN')

acspop16tr['pcnhwht1016'] = acspop16tr.pnhwht16.astype('float64').subtract(std0712.pnhwht10.astype('float64'),fill_value='NaN')
acspop16tr['pcnhblk1016'] = acspop16tr.pnhblk16.astype('float64').subtract(std0712.pnhblk10.astype('float64'),fill_value='NaN')
acspop16tr['pcasian1016'] = acspop16tr.pasian16.astype('float64').subtract(std0712.pasian10.astype('float64'),fill_value='NaN')
acspop16tr['pchisp1016'] = acspop16tr.phisp16.astype('float64').subtract(std0712.phisp10.astype('float64'),fill_value='NaN')

acspop16tr.head()

# %%
acshousing16tr = pd.read_csv('acs/acs_housing_2016_tr.csv')
acshousing16trcolumns = ['id','hu16','ohu16','pohu16','vac16','pvac16','own16','pown16',
                         'rent16','prent16','mhmval16','mhmval16a17','mrent16','mrent16a17']
acshousing16tr[acshousing16trcolumns]
acshousing16tr.head()

# %%
acshousing16tr.replace(to_replace='-',value=np.nan,inplace=True)

acshousing16tr['cmhmval0016a17'] = acshousing16tr.mhmval16a17.astype('float64').subtract(std9800.mhmval00a17.astype('float64'),fill_value='NaN')
acshousing16tr['pcmhmval0016a17'] = 100.0*(acshousing16tr.cmhmval0016a17.astype('float64')/std9800.mhmval00a17.astype('float64'))
acshousing16tr['cmrent0016a17'] = acshousing16tr.mrent16a17.astype('float64').subtract(std9800.mrent00a17.astype('float64'),fill_value='NaN')
acshousing16tr['pcmrent0016a17'] = 100.0*(acshousing16tr.cmrent0016a17.astype('float64')/std9800.mrent00a17.astype('float64'))

acshousing16tr['cmhmval1216a17'] = acshousing16tr.mhmval16a17.astype('float64').subtract(std0712.mhmval12a17.astype('float64'),fill_value='NaN')
acshousing16tr['pcmhmval1216a17'] = 100.0*(acshousing16tr.cmhmval0016a17.astype('float64')/std0712.mhmval12a17.astype('float64'))
acshousing16tr['cmrent1216a17'] = acshousing16tr.mrent16a17.astype('float64').subtract(std0712.mrent12a17.astype('float64'),fill_value='NaN')
acshousing16tr['pcmrent1216a17'] = 100.0*(acshousing16tr.cmrent0016a17.astype('float64')/std0712.mrent12a17.astype('float64'))

acshousing16tr.head()

# %%
acsincome1517tr = pd.read_csv('acs/acs_propsale_income_1517_tr.csv')
acsincome1517trcolumns = ['trtid10', 'hinc16','hinc16a17','hincw16','hincw16a17','hincb16','hincb16a17',
                          'hincn16','hincn16a17','hinca16','hinca16a17','hincp16','hincp16a17',
                          'hinco16','hinco16a17','hincm16','hincm16a17','hinch16','hinch16a17',
                          'meansp1517','minsp1517','maxsp1517','mediansp1517','stddevsp1517','totsp1517',
                          'nums1517','meansp1517a17','minsp1517a17','maxsp1517a17','mediansp1517a17',
                          'totsp1517a17','pir1517']
acsincome1517tr = acsincome1517tr[acsincome1517trcolumns]
acsincome1517tr.rename(columns={'trtid10':'id'},inplace=True)
acsincome1517tr.head()

# %%
acsincome1517tr.replace(to_replace='-',value=np.nan,inplace=True)

acsincome1517tr['chinc1216a17'] = acsincome1517tr.hinc16a17.astype('float64').subtract(std0712.hinc12a17.astype('float64'),fill_value='NaN')
acsincome1517tr['chincw1216a17'] = acsincome1517tr.hincw16a17.astype('float64').subtract(std0712.hincw12a17.astype('float64'),fill_value='NaN')
acsincome1517tr['chincb1216a17'] = acsincome1517tr.hincb16a17.astype('float64').subtract(std0712.hincb12a17.astype('float64'),fill_value='NaN')
acsincome1517tr['chinca1216a17'] = acsincome1517tr.hinca16a17.astype('float64').subtract(std0712.hinca12a17.astype('float64'),fill_value='NaN')
acsincome1517tr['chinch1216a17'] = acsincome1517tr.hinch16a17.astype('float64').subtract(std0712.hinch12a17.astype('float64'),fill_value='NaN')
acsincome1517tr['cmeansp0917a17'] = acsincome1517tr.meansp1517a17.astype('float64').subtract(std0712.meansp0709a17.astype('float64'),fill_value='NaN')
acsincome1517tr['cmediansp0917a17'] = acsincome1517tr.mediansp1517a17.astype('float64').subtract(std0712.mediansp0709a17.astype('float64'),fill_value='NaN')

acsincome1517tr['pchinc1216a17'] = 100.0*(acsincome1517tr.chinc1216a17.astype('float64')/std0712.hinc12a17.astype('float64'))
acsincome1517tr['pchincw1216a17'] = 100.0*(acsincome1517tr.chincw1216a17.astype('float64')/std0712.hincw12a17.astype('float64'))
acsincome1517tr['pchincb1216a17'] = 100.0*(acsincome1517tr.chincb1216a17.astype('float64')/std0712.hincb12a17.astype('float64'))
acsincome1517tr['pchinca1216a17'] = 100.0*(acsincome1517tr.chinca1216a17.astype('float64')/std0712.hinca12a17.astype('float64'))
acsincome1517tr['pchinch1216a17'] = 100.0*(acsincome1517tr.chinch1216a17.astype('float64')/std0712.hinch12a17.astype('float64'))
acsincome1517tr['pcmeansp0917a17'] = 100.0*(acsincome1517tr.cmeansp0917a17.astype('float64')/std0712.meansp0709a17.astype('float64'))
acsincome1517tr['pcmediansp0917a17'] = 100.0*(acsincome1517tr.cmediansp0917a17.astype('float64')/std0712.mediansp0709a17.astype('float64'))

acsincome1517tr['chinc0016a17'] = acsincome1517tr.hinc16a17.astype('float64').subtract(std9800.hinc00a17.astype('float64'),fill_value='NaN')
acsincome1517tr['chincw0016a17'] = acsincome1517tr.hincw16a17.astype('float64').subtract(std9800.hincw00a17.astype('float64'),fill_value='NaN')
acsincome1517tr['chincb0016a17'] = acsincome1517tr.hincb16a17.astype('float64').subtract(std9800.hincb00a17.astype('float64'),fill_value='NaN')
acsincome1517tr['chinca0016a17'] = acsincome1517tr.hinca16a17.astype('float64').subtract(std9800.hinca00a17.astype('float64'),fill_value='NaN')
acsincome1517tr['chinch0016a17'] = acsincome1517tr.hinch16a17.astype('float64').subtract(std9800.hinch00a17.astype('float64'),fill_value='NaN')
acsincome1517tr['cmeansp0017a17'] = acsincome1517tr.meansp1517a17.astype('float64').subtract(std9800.meansp9800a17.astype('float64'),fill_value='NaN')
acsincome1517tr['cmediansp0017a17'] = acsincome1517tr.mediansp1517a17.astype('float64').subtract(std9800.mediansp9800a17.astype('float64'),fill_value='NaN')

acsincome1517tr['pchinc0016a17'] = 100.0*(acsincome1517tr.chinc0016a17.astype('float64')/std9800.hinc00a17.astype('float64'))
acsincome1517tr['pchincw0016a17'] = 100.0*(acsincome1517tr.chincw0016a17.astype('float64')/std9800.hincw00a17.astype('float64'))
acsincome1517tr['pchincb0016a17'] = 100.0*(acsincome1517tr.chincb0016a17.astype('float64')/std9800.hincb00a17.astype('float64'))
acsincome1517tr['pchinca0016a17'] = 100.0*(acsincome1517tr.chinca0016a17.astype('float64')/std9800.hinca00a17.astype('float64'))
acsincome1517tr['pchinch0016a17'] = 100.0*(acsincome1517tr.chinch0016a17.astype('float64')/std9800.hinch00a17.astype('float64'))
acsincome1517tr['pcmeansp0017a17'] = 100.0*(acsincome1517tr.cmeansp0017a17.astype('float64')/std9800.meansp9800a17.astype('float64'))
acsincome1517tr['pcmediansp0017a17'] = 100.0*(acsincome1517tr.cmediansp0017a17.astype('float64')/std9800.mediansp9800a17.astype('float64'))

acsincome1517tr.head()

# %%
acseducation16tr = pd.read_csv('acs/acs_education_2016_tr.csv')
acseducation16trcolumns = ['id','ag25up16','colm16','colf16','col16','pcol16']
acseducation16tr = acseducation16tr[acseducation16trcolumns]
acseducation16tr.head()

# %%
acseducation16tr.replace(to_replace='-',value=np.nan,inplace=True)
acseducation16tr['pccol1216'] = acseducation16tr.pcol16.astype('float64').subtract(std0712.pcol12.astype('float64'),fill_value='NaN')
acseducation16tr['pccol0016'] = acseducation16tr.pcol16.astype('float64').subtract(std9800.pcol00.astype('float64'),fill_value='NaN')

acseducation16tr.head()

# %%
acs1517tr = pd.merge(acspop16tr,acshousing16tr,on='id')
acs1517tr = acs1517tr.merge(acsincome1517tr,on='id')
acs1517tr = acs1517tr.merge(acseducation16tr,on='id')
acs1517tr.head()

# %%
stdall.rename(columns={'trtid10':'id'},inplace=True)
ltdbacs7016 = pd.merge(stdall,acs1517tr,on='id')
ltdbacs7016.head()

# %%
ltdbacs7016.replace(to_replace='-',value='NaN',inplace=True)
ltdbacs7016.replace(to_replace=-np.inf,value='NaN',inplace=True)

# %%
ltdbacs7016.to_csv('durham_ltdbacs_7016_tr.csv',index=False,float_format='%.2f',na_rep='NaN')

# %%
ltdbacs7016tr = pd.read_csv('durham_ltdbacs_7016_tr.csv')

# %%
f = open('models_ltdbacs7016tr.py','w')

f.write('from django.db import models\n')
f.write('\n')
f.write('class LTDBACS_trts_7016(models.Model):\n')

for col in ltdbacs7016tr.columns:
    var = str(ltdbacs7016tr[col].max())
    digits = str(len(var)+1)
    decimal = str(len(var.split('.')))
    isnull = str(ltdbacs7016tr[col].isnull().values.any())
    if col == 'id':
        f.write('   '+col+' = models.TextField(12,primary_key=True)\n')
    else:
        f.write('   '+col+' = models.DecimalField(max_digits='+digits+',decimal_places='+decimal+',null='+isnull+')\n')

f.close()

# %%
f = open('serializers_ltdbacs7016tr.py','w')

f.write('class LTDBACS_trts_7016Serializer (serializers.ModelSerializer):\n')
f.write('    class Meta:\n')
f.write('        model = LTDBACS_trts_7016\n')
f.write('        fields = (')

columns = ltdbacs7016tr.columns

for column in columns:
    if column == columns[len(columns)-1]:
        f.write("'"+column+"'")
    else:
        f.write("'"+column+"',")
    
f.write(')\n')
f.close()

# %%
f = open('durham_ltdbacs_7016_tr.sql','w')

f.write('\copy datahub_be_app_ltdbacs_trts_7016(')
columns = ltdbacs7016tr.columns

for column in columns:
    if column == columns[len(columns)-1]:
        f.write(column)
    else:
        f.write(column+",")
    
f.write(") FROM 'durham_ltdbacs_7016_tr.csv' WITH DELIMITER ',' CSV HEADER;\n")
f.write('\n')
f.write('COMMIT;')
f.close()

# %%
mapdesc = pd.read_csv('ltdbacs_trts_vuemapmenu.csv',sep='|')
mapdesc.head()

# %%
columns = np.array(ltdbacs7016tr.columns)

f = open('ltdbacs_trts_vuemapmenu.json','w')
for column in columns:
    colyear = column[len(column)-2:]
    if colyear == '17':
        if column[len(column)-3:] == 'a17':
            if column[len(column)-7:len(column)-3].isnumeric() == True:
                colvar = column[:len(column)-7]
                colyr1 = column[len(column)-7:len(column)-5]
                colyr2 = column[len(column)-5:len(column)-3]
                if colyr1 == '98':
                    var = mapdesc.loc[mapdesc['var'] == colvar]
                    f.write("        {label: '"+var.desc.to_string(index=False)+" between 19"+colyr1+
                            " and 20"+colyr2+", Adjusted to 2017 Dollars"+
                            "', value: '"+column+"', type: 'trts'},\n")
                else:
                    var = mapdesc.loc[mapdesc['var'] == colvar]
                    f.write("        {label: '"+var.desc.to_string(index=False)+" between 20"+colyr1+
                            " and 20"+colyr2+", Adjusted to 2017 Dollars"+
                            "', value: '"+column+"', type: 'trts'},\n")
            elif column[len(column)-7:len(column)-3].isnumeric() == False:
                colvar = column[:len(column)-5]
                colyr = column[len(column)-5:len(column)-3]
                if int(colyr) < 20:
                    var = mapdesc.loc[mapdesc['var'] == colvar]
                    f.write("        {label: '"+var.desc.to_string(index=False)+" in 20"+colyr+
                            ", Adjusted to 2017 Dollars"+
                            "', value: '"+column+"', type: 'trts'},\n")
                elif int(colyr) > 20:
                    var = mapdesc.loc[mapdesc['var'] == colvar]
                    f.write("        {label: '"+var.desc.to_string(index=False)+" in 19"+colyr+
                            ", Adjusted to 2017 Dollars"+
                            "', value: '"+column+"', type: 'trts'},\n")
                else:
                    print(colyr)
            else:
                print(column)
        else:
            colvar = column[:len(column)-4]
            var = mapdesc.loc[mapdesc['var'] == colvar]
            f.write("        {label: '"+var.desc.to_string(index=False)+" between 2015 and 2017"
                    "', value: '"+column+"', type: 'trts'},\n")
    else:
        if column[len(column)-4:].isnumeric() == True:
            colvar = column[:len(column)-4]
            colyr1 = column[len(column)-4:len(column)-2]
            colyr2 = column[len(column)-2:]
            if colyr1 == '98':
                var = mapdesc.loc[mapdesc['var'] == colvar]
                f.write("        {label: '"+var.desc.to_string(index=False)+" between 19"+colyr1+
                        " and 20"+colyr2+", "+
                        "', value: '"+column+"', type: 'trts'},\n")
            else:
                if column == columns[len(columns)-1]:
                    var = mapdesc.loc[mapdesc['var'] == colvar]
                    f.write("        {label: '"+var.desc.to_string(index=False)+" between 20"+colyr1+
                            " and 20"+colyr2+", "+
                            "', value: '"+column+"', type: 'trts'}\n")
                else:
                    var = mapdesc.loc[mapdesc['var'] == colvar]
                    f.write("        {label: '"+var.desc.to_string(index=False)+" between 20"+colyr1+
                            " and 20"+colyr2+", "+
                            "', value: '"+column+"', type: 'trts'},\n")
            
        elif column[len(column)-4:].isnumeric() == False:
            colvar = column[:len(column)-2]
            colyr = column[len(column)-2:]
            if colyr == 'id':
                print(colyr)
            elif int(colyr) < 20:
                var = mapdesc.loc[mapdesc['var'] == colvar]
                f.write("        {label: '"+var.desc.to_string(index=False)+" in 20"+colyr+
                        "', value: '"+column+"', type: 'trts'},\n")
            elif int(colyr) > 20:
                var = mapdesc.loc[mapdesc['var'] == colvar]
                f.write("        {label: '"+var.desc.to_string(index=False)+" in 19"+colyr+
                        "', value: '"+column+"', type: 'trts'},\n")
            else:
                print(colyr)
        else:
            print(column)
            
f.write('\n')

for column in columns:
    colyear = column[len(column)-2:]
    if colyear == '17':
        if column[len(column)-3:] == 'a17':
            if column[len(column)-7:len(column)-3].isnumeric() == True:
                colvar = column[:len(column)-7]
                var = mapdesc.loc[mapdesc['var'] == colvar]
                f.write("      else if (this.select.value === '"+column+"' && this.select.type === 'trts') {\n")
                f.write("        desc = '"+var.desc.to_string(index=False)+
                        ", Adjusted to 2017 Dollars: ' + numberWithCommas(this.currentDurhamtr."+column+")\n")
                f.write("      }\n")                
            elif column[len(column)-7:len(column)-3].isnumeric() == False:
                colvar = column[:len(column)-5]
                var = mapdesc.loc[mapdesc['var'] == colvar]
                f.write("      else if (this.select.value === '"+column+"' && this.select.type === 'trts') {\n")
                f.write("        desc = '"+var.desc.to_string(index=False)+
                        ", Adjusted to 2017 Dollars: ' + numberWithCommas(this.currentDurhamtr."+column+")\n")
                f.write("      }\n")
        else:
            colvar = column[:len(column)-4]
            var = mapdesc.loc[mapdesc['var'] == colvar]
            f.write("      else if (this.select.value === '"+column+"' && this.select.type === 'trts') {\n")
            f.write("        desc = '"+var.desc.to_string(index=False)+", '" 
                    + " + numberWithCommas(this.currentDurhamtr."+column+")\n")
            f.write("      }\n")
    else:
        if column[len(column)-4:].isnumeric() == True:
            colvar = column[:len(column)-4]
            var = mapdesc.loc[mapdesc['var'] == colvar]
            f.write("      else if (this.select.value === '"+column+"' && this.select.type === 'trts') {\n")
            f.write("        desc = '"+var.desc.to_string(index=False)+
                    ": ' + numberWithCommas(this.currentDurhamtr."+column+")\n")
            f.write("      }\n")            
        elif column[len(column)-4:].isnumeric() == False:
            colvar = column[:len(column)-2]
            colyr = column[len(column)-2:]
            if colyr == 'id':
                print(colyr)
            elif column == columns[1]:
                var = mapdesc.loc[mapdesc['var'] == colvar]
                f.write("      if (this.select.value === '"+column+"' && this.select.type === 'trts') {\n")
                f.write("        desc = '"+var.desc.to_string(index=False)+
                        ": ' + numberWithCommas(this.currentDurhamtr."+column+")\n")
                f.write("      }\n")                
            else:
                var = mapdesc.loc[mapdesc['var'] == colvar]
                f.write("      else if (this.select.value === '"+column+"' && this.select.type === 'trts') {\n")
                f.write("        desc = '"+var.desc.to_string(index=False)+
                        ": ' + numberWithCommas(this.currentDurhamtr."+column+")\n")
                f.write("      }\n")
        else:
            print(column)

f.close()

# %%
f = open('schema_ltdbacs7016tr.sql','w')

f.write('SET CLIENT_ENCODING TO UTF8;\n')
f.write('SET STANDARD_CONFORMING_STRINGS TO ON;\n')
f.write('BEGIN;\n')
f.write('CREATE TABLE durham_ltdbacs_7016_tr (gid serial,\n')

for col in ltdbacs7016tr.columns:
    var = str(ltdbacs7016tr[col].max())
    digits = str(len(var)+1)
    decimal = str(len(var.split('.')))
    isnull = str(ltdbacs7016tr[col].isnull().values.any())
    if col == 'id':
        f.write('   '+col+' VARCHAR(12),\n')
    else:
        if col == ltdbacs7016tr.columns[len(ltdbacs7016tr.columns)-1]:
            f.write('   '+col+' DOUBLE PRECISION);\n')
        else:
            f.write('   '+col+' DOUBLE PRECISION,\n')
            
f.write('ALTER TABLE durham_ltdbacs_7016_tr ADD PRIMARY KEY (gid);\n')
f.write('COMMIT;\n')
f.close()
