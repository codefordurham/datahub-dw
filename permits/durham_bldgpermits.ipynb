# %%
import pandas as pd

# %%
permitData = pd.read_csv('durham_bldgpermits.csv', index_col=0)

# %%
permitData
# Out:
#     BLDB_ACTIVITY       BLDB_ACTIVITY_1    BLD_Cost             BLD_Type  \
# 0              MN       Minimum Housing    14500.00               Duplex
# 1             ADD              Addition    20000.00  Single Family House
# 2             ADD              Addition    10000.00  Single Family House
# 3             NEW                   New    93192.00  Single Family House
# 4             NEW                   New   146256.00  Single Family House
# 5           I_ALT  Interior Alterations     6000.00  Single Family House
# 6             ADD              Addition    11900.00  Single Family House
# 7              RP                Repair     4716.00  Single Family House
# 8              MN       Minimum Housing    16800.00  Single Family House
# 9              RP                Repair    12000.00  Single Family House
# 10            NEW                   New   191500.00  Single Family House
# 11            ADD              Addition     8000.00  Single Family House
# ...

# %%
import time

# %%
to_local_datetime = lambda x: time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(x/1000))

# %%
permitData['CO_SIGNOFF_DATE'].fillna(value=0, inplace=True)

# %%
permitData['CO_SIGNOFF_DATE'] = permitData['CO_SIGNOFF_DATE'].apply(to_local_datetime)

# %%
permitData
# Out:
#     BLDB_ACTIVITY       BLDB_ACTIVITY_1    BLD_Cost             BLD_Type  \
# 0              MN       Minimum Housing    14500.00               Duplex
# 1             ADD              Addition    20000.00  Single Family House
# 2             ADD              Addition    10000.00  Single Family House
# 3             NEW                   New    93192.00  Single Family House
# 4             NEW                   New   146256.00  Single Family House
# 5           I_ALT  Interior Alterations     6000.00  Single Family House
# 6             ADD              Addition    11900.00  Single Family House
# 7              RP                Repair     4716.00  Single Family House
# 8              MN       Minimum Housing    16800.00  Single Family House
# 9              RP                Repair    12000.00  Single Family House
# 10            NEW                   New   191500.00  Single Family House
# 11            ADD              Addition     8000.00  Single Family House
# ...

# %%
pending = permitData.loc[permitData['PmtStatus'] == 'CO Pending']

# %%
pending
# Out:
#     BLDB_ACTIVITY       BLDB_ACTIVITY_1    BLD_Cost               BLD_Type  \
# 462           ADD              Addition    32000.00    Single Family House
# 610           ADD              Addition    20000.00    Single Family House
# 656           ADD              Addition     3000.00        Non-Residential
# 665           ADD              Addition   104934.06        Non-Residential
# 915            MN       Minimum Housing     8900.00    Single Family House
# 940           ADD              Addition   312000.00    Single Family House
# 272         I_ALT  Interior Alterations    10500.00        Non-Residential
# 456            OT                 Other     1000.00    Accessory Structure
# 461           ALT           Alterations    19631.00        Non-Residential
# 923          MOVE                Moving      500.00    Single Family House
# 924          MOVE                Moving      500.00    Single Family House
# ...

# %%
list(permitData.columns.values)
# Out:
# ['BLDB_ACTIVITY',
#  'BLDB_ACTIVITY_1',
#  'BLD_Cost',
#  'BLD_Type',
#  'COMMENTS',
#  'CO_SIGNOFF_DATE',
#  'DESCRIPTION',
#  'DWELLING_UNITS',
#  'ESTIMATED_ELEC_COST',
#  'ESTIMATED_MECH_COST',
#  'ESTIMATED_OTH_COST',
#  'ISSUE_DATE',
#  'NO_PARKING',
#  'OBJECTID',
#  'OBJECTID_12_13',
#  'Occupancy',
#  'PARCEL_ID',
#  'PID',
#  'PIN',
#  'PIN15',
#  'PROJECT_NAME',
#  'PROJECT_TYPE',
#  'PermitNum',
#  'PmtStatus',
#  'SQFT_FLOOR',
#  'SQFT_LAND',
#  'STArea__',
#  'STLength__',
#  'TOTAL_ROOMS',
#  'TYPE',
#  'geometry']

# %%
pending = permitData.loc[(permitData['PmtStatus'] == 'CO Pending') & (permitData['TYPE'] == 'RESI')]

# %%
pending
# Out:
#     BLDB_ACTIVITY       BLDB_ACTIVITY_1  BLD_Cost             BLD_Type  \
# 462           ADD              Addition     32000  Single Family House
# 610           ADD              Addition     20000  Single Family House
# 915            MN       Minimum Housing      8900  Single Family House
# 940           ADD              Addition    312000  Single Family House
# 272         I_ALT  Interior Alterations     10500      Non-Residential
# 456            OT                 Other      1000  Accessory Structure
# 923          MOVE                Moving       500  Single Family House
# 924          MOVE                Moving       500  Single Family House
# 929            OT                 Other      9000  Accessory Structure
# 769            MN       Minimum Housing      5000  Single Family House
# 426          MOVE                Moving      5000  Single Family House
# 621           ALT           Alterations      5668  Single Family House
# ...

# %%
multi = permitData.loc[(permitData['TYPE'] == 'MULTI_FAMILY') & (permitData['BLDB_ACTIVITY'] == 'NEW') & (permitData['PmtStatus'] != 'Void')]

# %%
multi
# Out:
#     BLDB_ACTIVITY BLDB_ACTIVITY_1    BLD_Cost              BLD_Type  \
# 799           NEW             New   177408.00                Duplex
# 801           NEW             New   177408.00                Duplex
# 79            NEW             New   140000.00                Duplex
# 80            NEW             New   140000.00                Duplex
# 156           NEW             New   275000.00                Duplex
# 223           NEW             New   198528.00                Duplex
# 305           NEW             New   320232.00                Duplex
# 725           NEW             New    97458.00   Single Family House
# 459           NEW             New   120000.00                Duplex
# 665           NEW             New    90000.00                Duplex
# 961           NEW             New   178200.00   Single Family House
# 579           NEW             New    43560.00                Duplex
# 580           NEW             New    43560.00                Duplex
# ...

# %%
multibldgs = permitData.loc[(permitData['TYPE'] == 'MULTI_FAMILY') & (permitData['BLDB_ACTIVITY'] == 'NEW') & (permitData['PmtStatus'] != 'Void')]['PARCEL_ID']

# %%
multibldgs.head()
# Out:
# 799    100699
# 801    100700
# 79     103806
# 80     103806
# 156    101726
# Name: PARCEL_ID, dtype: int64

# %%
sample_bldg = permitData.loc[(permitData['PARCEL_ID'] == 100699)]

# %%
sample_bldg
# Out:
#     BLDB_ACTIVITY       BLDB_ACTIVITY_1  BLD_Cost BLD_Type  \
# 798         I_ALT  Interior Alterations    177408   Duplex
# 799           NEW                   New    177408   Duplex
#
#                                               COMMENTS      CO_SIGNOFF_DATE  \
# 798  Permmit voided, replaced by BP 1010563   -  Ne...  1969-12-31 19:00:00
# 799                                     Units A and B.  2010-09-17 11:27:30
#
#                                            DESCRIPTION  DWELLING_UNITS  \
# 798  UNITS A & B; DUPLEX RENOVATION, EXISTING FOOTI...               2
# 799  Duplex; new construction (replaces BP# 0913031...               2
#
#      ESTIMATED_ELEC_COST  ESTIMATED_MECH_COST  \
# 798                  NaN                  NaN
# 799                  NaN                  NaN
#
#                            ...                          PROJECT_TYPE  \
# 798                        ...                                   NaN
# ...

# %%
refinedPermitData = permitData[['BLDB_ACTIVITY', 'BLD_Cost', 'BLD_Type', 'CO_SIGNOFF_DATE', 'DWELLING_UNITS', 'Occupancy', 'PARCEL_ID', 'PROJECT_NAME', 'PROJECT_TYPE', 'PermitNum', 'PmtStatus', 'SQFT_FLOOR', 'SQFT_LAND', 'STArea__', 'STLength__', 'TOTAL_ROOMS', 'TYPE', 'geometry']]

# %%
refinedPermitData.head()
# Out:
#   BLDB_ACTIVITY  BLD_Cost             BLD_Type      CO_SIGNOFF_DATE  \
# 0            MN     14500               Duplex  2014-05-18 04:28:06
# 1           ADD     20000  Single Family House  2015-09-25 07:24:58
# 2           ADD     10000  Single Family House  2018-07-11 04:40:46
# 3           NEW     93192  Single Family House  1969-12-31 19:00:00
# 4           NEW    146256  Single Family House  2008-07-28 04:21:18
#
#    DWELLING_UNITS      Occupancy  PARCEL_ID PROJECT_NAME PROJECT_TYPE  \
# 0             NaN         Duplex     101008          NaN          NaN
# 1               1  Single Family     119617          NaN          NaN
# 2             NaN  Single Family     108966          NaN          NaN
# 3               1  Single Family     120054          NaN          NaN
# 4               1  Single Family     120054          NaN          NaN
#
#    PermitNum  PmtStatus  SQFT_FLOOR  SQFT_LAND      STArea__  STLength__  \
# ...

# %%
parcelData = pd.read_csv('parcels.csv', sep=';', error_bad_lines=False, low_memory=False)

# %%
parcelData.head()
# Out:
#                                            geo_shape  \
# 0  {"type": "Polygon", "coordinates": [[[-78.9839...
# 1  {"type": "Polygon", "coordinates": [[[-78.9276...
# 2  {"type": "Polygon", "coordinates": [[[-78.9283...
# 3  {"type": "Polygon", "coordinates": [[[-78.9244...
# 4  {"type": "Polygon", "coordinates": [[[-78.9910...
#
#                     geo_point_2d              PIN  OBJECTID  PARCEL_ID  \
# 0    35.905590647, -78.984240036  0708-03-44-6564   1095703     142267
# 1  35.9048801266, -78.9277329858  0728-03-14-3298   1095710     149800
# 2  35.9043448072, -78.9284296507  0728-03-14-1098   1095715     149785
# 3  35.9041987096, -78.9246913046  0728-03-24-3003   1095717     149748
# 4  35.9067115164, -78.9911806456  0708-03-24-6903   1095726     142488
#
#           SITE_ADDRE  Location FRONT_DIM  POLY_ACRE  SUM_ACRE  \
# 0       2 FOXHALL PL       NaN     80.00      0.326     0.327
# 1         4 UPTON CT       NaN    103.34      0.231     0.231
# ...

# %%
list(parcelData.columns.values)
# Out:
# ['geo_shape',
#  'geo_point_2d',
#  'PIN',
#  'OBJECTID',
#  'PARCEL_ID',
#  'SITE_ADDRE',
#  'Location',
#  'FRONT_DIM',
#  'POLY_ACRE',
#  'SUM_ACRE',
#  'OLD_ID',
#  'USERINT',
#  'CITY_CODE',
#  'ACCT_',
#  'OWNAM1',
#  'OWNAM2',
#  'OWNAM3',
#  'OWADR1',
#  'OWADR2',
#  'OWADR3',
#  'OWADR4',
#  'OWCITY',
#  'OWSTA',
#  'OWZIPA',
#  'DIST_CODE',
#  'SplitTaxDis',
#  'SplitTaxDec',
#  'LAND_USE',
#  'LANDUSE_DESC',
#  'NBR_CLASS',
#  'NBR_CODE',
#  'EXEMPT_CODE',
#  'LAND_VALUE',
#  'BLDG_VALUE',
#  'TOTAL_VALU',
#  'DEED_BOOK',
#  'DEED_PAGE',
#  'PLAT_BOOK',
#  'PLAT_PAGE',
#  'DATE_SOLD',
#  'SALE_PRICE',
#  'SUBD_ID',
#  'SUBD_DESC',
#  'OWNER_NAME',
#  'OWNER_ADDR',
#  'CLASS_CODE',
#  'Shape.STArea()',
#  'Shape.STLength()']

# %%
refinedParcelData = parcelData[['PARCEL_ID', 'POLY_ACRE', 'SUM_ACRE', 'OWSTA', 'DIST_CODE', 'LAND_USE', 'LANDUSE_DESC', 'LAND_VALUE', 'BLDG_VALUE', 'TOTAL_VALU', 'DATE_SOLD', 'SALE_PRICE']]

# %%
refinedParcelData.head()
# Out:
#    PARCEL_ID  POLY_ACRE  SUM_ACRE OWSTA  DIST_CODE  LAND_USE  \
# 0     142267      0.326     0.327    NC          1       111
# 1     149800      0.231     0.231    NC          1       111
# 2     149785      0.224     0.225    NC          1       111
# 3     149748      0.294     0.293    NC          1       111
# 4     142488      0.043     0.044    NC          1       122
#
#              LANDUSE_DESC  LAND_VALUE  BLDG_VALUE  TOTAL_VALU  \
# 0           RES/ 1-FAMILY       59715      214480      274195
# 1           RES/ 1-FAMILY       49240      268372      317612
# 2           RES/ 1-FAMILY       49000      225506      274506
# 3           RES/ 1-FAMILY       51720      219012      270732
# 4  RES/ TOWNHOUSE W/ LAND       40000      125958      165958
#
#                    DATE_SOLD  SALE_PRICE
# 0  1996-12-31T19:00:00-05:00           0
# 1  2005-12-01T19:00:00-05:00      295000
# 2  2005-03-30T19:00:00-05:00      259000
# 3  2009-09-29T20:00:00-04:00      265000
# ...

# %%
refinedParcelData.to_csv('parcels.csv')

# %%
parcelPermitData = refinedPermitData.set_index('PARCEL_ID').join(refinedParcelData.set_index('PARCEL_ID'))

# %%
parcelPermitData.head()
# Out:
#           BLDB_ACTIVITY  BLD_Cost         BLD_Type      CO_SIGNOFF_DATE  \
# PARCEL_ID
# 100000               OT    138453  Non-Residential  2010-09-24 09:36:55
# 100000            I_ALT    185704  Non-Residential  2008-08-12 12:12:08
# 100000            I_ALT     53133  Non-Residential  2008-08-20 04:20:00
# 100000            I_ALT     54741  Non-Residential  2009-10-30 05:01:36
# 100000               RP      7661  Non-Residential  2010-04-26 12:19:57
#
#            DWELLING_UNITS     Occupancy                   PROJECT_NAME  \
# PARCEL_ID
# 100000                NaN  Assembly (3)          INSTALL HANDICAP LIFT
# 100000                NaN      Business  CARR BLDG CLASSRM RENOVATIONS
# 100000                NaN      Business       Carr Building - Room 243
# 100000                NaN      Business           steve 868-3452  jose
# 100000                NaN      Business                            NaN
#
#           PROJECT_TYPE  PermitNum  PmtStatus    ...      SUM_ACRE  OWSTA  \
# ...

# %%
parcelPermitData.tail()
# Out:
#           BLDB_ACTIVITY  BLD_Cost             BLD_Type      CO_SIGNOFF_DATE  \
# PARCEL_ID
# 224226              NEW    293040  Single Family House  1969-12-31 19:00:00
# 224227              NEW    308220  Single Family House  1969-12-31 19:00:00
# 224228              NEW    230472  Single Family House  1969-12-31 19:00:00
# 224229              NEW    263076  Single Family House  1969-12-31 19:00:00
# 224230              NEW    299640  Single Family House  1969-12-31 19:00:00
#
#            DWELLING_UNITS      Occupancy PROJECT_NAME PROJECT_TYPE  PermitNum  \
# PARCEL_ID
# 224226                  1  Single Family          NaN          NaN   18102949
# 224227                  1  Single Family          NaN          NaN   18102944
# 224228                  1  Single Family          NaN          NaN   18102946
# 224229                  1  Single Family          NaN          NaN   18102948
# 224230                  1  Single Family          NaN          NaN   18102950
#
# ...

# %%
parcelPermitData
# Out:
#           BLDB_ACTIVITY  BLD_Cost                                   BLD_Type  \
# PARCEL_ID
# 100000               OT    138453                            Non-Residential
# 100000            I_ALT    185704                            Non-Residential
# 100000            I_ALT     53133                            Non-Residential
# 100000            I_ALT     54741                            Non-Residential
# 100000               RP      7661                            Non-Residential
# 100000               RP     22986                            Non-Residential
# 100000               RP     30649                            Non-Residential
# 100000               RP     30649                            Non-Residential
# 100000               RP     15324                            Non-Residential
# 100000               RP     30649                            Non-Residential
# 100000               RP     28733                            Non-Residential
# ...

# %%
parcelPermitData.to_csv('ParcelPermits.csv')
