# %%
import pandas as pd

# %%
permitData = pd.read_csv('durham_bldgpermits.csv')

# %%
permitData
# Out:
#        Unnamed: 0 BLDB_ACTIVITY       BLDB_ACTIVITY_1    BLD_Cost  \
# 0               0            MN       Minimum Housing    14500.00
# 1               1           ADD              Addition    20000.00
# 2               2           ADD              Addition    10000.00
# 3               3           NEW                   New    93192.00
# 4               4           NEW                   New   146256.00
# 5               5         I_ALT  Interior Alterations     6000.00
# 6               6           ADD              Addition    11900.00
# 7               7            RP                Repair     4716.00
# 8               8            MN       Minimum Housing    16800.00
# 9               9            RP                Repair    12000.00
# 10             10           NEW                   New   191500.00
# 11             11           ADD              Addition     8000.00
# 12             12         I_ALT  Interior Alterations    13000.00
# ...
